# %%
import pandas as pd

# %%
#Loading the train and test data.
train=pd.read_csv('/home/sagar/Downloads/adult.data')
test=pd.read_csv('/home/sagar/Downloads/adult.test')

# %%
#Renaming the columns of a Dataset

train.columns = [
  'age','workclass','fnlwgt','education','education-num','marital-status',
    'occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country','income-group']

test.columns=[ 'age','workclass','fnlwgt','education','education-num','marital-status',
    'occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country','income-group']

# %%
import numpy
train.replace(" ", numpy.nan, inplace=True)
test.replace(" ",numpy.nan,inplace=True)

# %%
#Checking whether the above query worked or not.
train.head(150)
# Out:
#      age          workclass  fnlwgt      education  education-num  \
# 0     50   Self-emp-not-inc   83311      Bachelors             13
# 1     38            Private  215646        HS-grad              9
# 2     53            Private  234721           11th              7
# 3     28            Private  338409      Bachelors             13
# 4     37            Private  284582        Masters             14
# 5     49            Private  160187            9th              5
# 6     52   Self-emp-not-inc  209642        HS-grad              9
# 7     31            Private   45781        Masters             14
# 8     42            Private  159449      Bachelors             13
# 9     37            Private  280464   Some-college             10
# 10    30          State-gov  141297      Bachelors             13
# 11    23            Private  122272      Bachelors             13
# 12    32            Private  205019     Assoc-acdm             12
# ...

# %%
#taking out columns of less importance.
train.drop(['education-num','capital-gain','capital-loss'], axis = 1, inplace = True)
test.drop(['education-num','capital-gain','capital-loss'], axis = 1, inplace = True)

# %%
train.describe()
# Out:
#                 age        fnlwgt  hours-per-week
# count  32560.000000  3.256000e+04    32560.000000
# mean      38.581634  1.897818e+05       40.437469
# std       13.640642  1.055498e+05       12.347618
# min       17.000000  1.228500e+04        1.000000
# 25%       28.000000  1.178315e+05       40.000000
# 50%       37.000000  1.783630e+05       40.000000
# 75%       48.000000  2.370545e+05       45.000000
# max       90.000000  1.484705e+06       99.000000

# %% [markdown]
# # Univariate Analysis.

# %%
#Creating a group of names of categorical variables.

categorical_var=train.dtypes.loc[train.dtypes=='object'].index

# %%
#Finding the unique values in the categorical variables. 

train[categorical_var].apply(lambda x: len(x.unique()))
# Out:
# workclass          9
# education         16
# marital-status     7
# occupation        15
# relationship       6
# race               5
# sex                2
# native-country    42
# income-group       2
# dtype: int64

# %% [markdown]
# We will now Investigate at the catgorical variables.

# %%
#Analysing the variable race

train['race'].value_counts()
# Out:
#  White                 27815
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: race, dtype: int64

# %%
train['race'].value_counts()/train.shape[0]
# Out:
#  White                 0.854269
#  Black                 0.095946
#  Asian-Pac-Islander    0.031910
#  Amer-Indian-Eskimo    0.009552
#  Other                 0.008323
# Name: race, dtype: float64

# %%
train['native-country'].value_counts()/train.shape[0]
# Out:
#  United-States                 0.895854
#  Mexico                        0.019748
#  Philippines                   0.006081
#  Germany                       0.004208
#  Canada                        0.003716
#  Puerto-Rico                   0.003501
#  El-Salvador                   0.003256
#  India                         0.003071
#  Cuba                          0.002918
#  England                       0.002764
#  Jamaica                       0.002488
#  South                         0.002457
#  China                         0.002303
#  Italy                         0.002242
#  Dominican-Republic            0.002150
#  Vietnam                       0.002058
#  Guatemala                     0.001966
#  Japan                         0.001904
#  Poland                        0.001843
#  Columbia                      0.001812
#  Taiwan                        0.001566
#  Haiti                         0.001351
#  Iran                          0.001321
# ...

# %%
train['income-group'].value_counts()/train.shape[0]
# Out:
#  <=50K    0.759183
#  >50K     0.240817
# Name: income-group, dtype: float64

# %%
train['marital-status'].value_counts()/train.shape[0]
# Out:
#  Married-civ-spouse       0.459951
#  Never-married            0.328071
#  Divorced                 0.136456
#  Separated                0.031480
#  Widowed                  0.030498
#  Married-spouse-absent    0.012838
#  Married-AF-spouse        0.000706
# Name: marital-status, dtype: float64

# %% [markdown]
# # Multi Variate analysis.
#
# categorical - categorical
#
# continuous - continuous
#
# categorical - continuous

# %%
ct=pd.crosstab(train['sex'],train['income-group'],margins=True,normalize='index')
ct

#pd.crosstab(train['sex'],train['income-group']).apply(lambda r: r/r.sum(), axis=1)
# Out:
# income-group     <=50K      >50K
# sex
#  Female       0.890539  0.109461
#  Male         0.694249  0.305751
# All           0.759183  0.240817

# %%
# %matplotlib inline
ct.iloc[:-1,:-1].plot(kind='bar', stacked = True, color=['blue','red'] ,grid = False)

# %%
def perc(ser):
    return ser/float(ser[-1])
ct2=ct.apply(perc,axis=1)
ct2.iloc[:-1,:-1].plot(kind='bar',stacked= False ,color = ['red','blue'], grid= False)

# %%
train.plot('age','hours-per-week',kind='scatter',color= 'green')

# %%
train.boxplot(column='hours-per-week',by='sex')

# %%
#Finding correlation between  Age and Hours-per-week
train['age'].corr(train['hours-per-week'])
# Out:
# 0.06875574320157962

# %%
ct3=pd.crosstab(train['occupation'],train['income-group'],margins=True,normalize='index')
ct3
# Out:
# income-group           <=50K      >50K
# occupation
#  Adm-clerical       0.865482  0.134518
#  Armed-Forces       0.888889  0.111111
#  Craft-repair       0.773359  0.226641
#  Exec-managerial    0.515986  0.484014
#  Farming-fishing    0.884306  0.115694
#  Handlers-cleaners  0.937226  0.062774
#  Machine-op-inspct  0.875125  0.124875
#  Other-service      0.958422  0.041578
#  Priv-house-serv    0.993289  0.006711
#  Prof-specialty     0.550966  0.449034
#  Protective-serv    0.674884  0.325116
#  Sales              0.730685  0.269315
#  Tech-support       0.695043  0.304957
#  Transport-moving   0.799624  0.200376
# All                 0.750952  0.249048

# %%
# import numpy
# train.replace(" ", numpy.nan, inplace=True)
# #train.isna()

# %% [markdown]
# # Missing values Treatment.

# %%
# test.replace(" ",numpy.nan,inplace=True)

# %%
train.apply(lambda x: sum(x.isna()))
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# hours-per-week       0
# native-country     583
# income-group         0
# dtype: int64

# %%
test.apply(lambda x: sum(x.isna()))
# Out:
# age                 0
# workclass         963
# fnlwgt              0
# education           0
# marital-status      0
# occupation        966
# relationship        0
# race                0
# sex                 0
# hours-per-week      0
# native-country    274
# income-group        0
# dtype: int64

# %%
from scipy.stats import mode

# %%
mode(train['workclass'].astype(str)).mode[0]
# Out:
# /home/sagar/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# ' Private'

# %%
var_to_impute = ['workclass','occupation','native-country']
for var in var_to_impute:
    train[var].fillna(mode(train[var].astype(str)).mode[0],inplace=True)
    test[var].fillna(mode(test[var].astype(str)).mode[0],inplace=True)
# Out:
# /home/sagar/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)

# %%
train.apply(lambda x: sum(x.isna()))
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# hours-per-week    0
# native-country    0
# income-group      0
# dtype: int64

# %%
test.apply(lambda x: sum(x.isna()))
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# hours-per-week    0
# native-country    0
# income-group      0
# dtype: int64

# %% [markdown]
# # Outliers Treatment.
#
# There are no Outliers as such.Even I dont have a ID column in my dataset.

# %%
# %matplotlib inline

# train.plot('hours-per-week',"age")

# %% [markdown]
# # Variable Transformation

# %%
train.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# hours-per-week     int64
# native-country    object
# income-group      object
# dtype: object

# %%
train['workclass'].value_counts()/train.shape[0]
# Out:
#  Private             0.753440
#  Self-emp-not-inc    0.078041
#  Local-gov           0.064281
#  State-gov           0.039834
#  Self-emp-inc        0.034275
#  Federal-gov         0.029484
#  Without-pay         0.000430
#  Never-worked        0.000215
# Name: workclass, dtype: float64

# %%
categories_to_combine = ['State-gov','Self-emp-inc','Federal-gov','Without-pay','Never-worked']

# %%
for cat in categories_to_combine:
    train['workclass'].replace({cat:'others'},inplace=True)
    test['workclass'].replace({cat:'others'},inplace=True)

# %%
train['workclass'].value_counts()/train.shape[0]
# Out:
#  Private             0.753440
#  Self-emp-not-inc    0.078041
#  Local-gov           0.064281
#  State-gov           0.039834
#  Self-emp-inc        0.034275
#  Federal-gov         0.029484
#  Without-pay         0.000430
#  Never-worked        0.000215
# Name: workclass, dtype: float64

# %%
for col in categorical_var:
    frq = train[col].value_counts()/train.shape[0]
    categories_to_combine= frq.loc[frq.values<0.05].index
    
    
    for cat in categories_to_combine:
        
             train[col].replace({cat:'others'},inplace=True)
             test[col].replace({cat:'others'},inplace=True)

# %%
test[categorical_var].apply(lambda x: len(x.unique()))
# Out:
# workclass         4
# education         5
# marital-status    4
# occupation        8
# relationship      5
# race              3
# sex               2
# native-country    2
# income-group      2
# dtype: int64

# %%
train[categorical_var].apply(lambda x: len(x.unique()))
# Out:
# workclass         4
# education         5
# marital-status    4
# occupation        8
# relationship      5
# race              3
# sex               2
# native-country    2
# income-group      2
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
#converting all categorical variables into encoded format
le = LabelEncoder()

for var in categorical_var:
    train[var]=le.fit_transform(train[var])
    test[var]=le.fit_transform(test[var])

# %%
train.dtypes
# Out:
# age               int64
# workclass         int64
# fnlwgt            int64
# education         int64
# marital-status    int64
# occupation        int64
# relationship      int64
# race              int64
# sex               int64
# hours-per-week    int64
# native-country    int64
# income-group      int64
# dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dependent_variable = 'income-group'
independent_variable =  [x for x in train.columns if x not in dependent_variable]

# %%
model = DecisionTreeClassifier(max_depth=10,min_samples_leaf=100,max_features='sqrt')

model.fit(train[independent_variable],train[dependent_variable])
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=100, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
predictions_train= model.predict(train[independent_variable])
predictions_test=model.predict(test[independent_variable])

# %%
from sklearn.metrics import accuracy_score

# %%
acc_train=accuracy_score(train[dependent_variable],predictions_train)
acc_train
# Out:
# 0.8168611793611794

# %%
acc_test=accuracy_score(test[dependent_variable],predictions_test)
acc_test
# Out:
# 0.8106879606879607
